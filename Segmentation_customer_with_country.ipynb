# %% [markdown]
# <a href="https://colab.research.google.com/github/chejige/Customer-Segmentation-Kmeans-clustering-/blob/main/Segmentation_customer_with_country.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U dataprep
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.5 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 965 kB 42.4 MB/s
# ...
#      |████████████████████████████████| 133 kB 57.6 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.9 MB/s
# ...
#      |████████████████████████████████| 943 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 749 kB 57.0 MB/s
# ...
#      |████████████████████████████████| 50 kB 6.4 MB/s
# ...
#      |████████████████████████████████| 78 kB 6.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 1.0 MB 46.2 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 70.4 MB/s
# ...
#      |████████████████████████████████| 96 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 232 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 45.6 MB/s
# ...

# %%
import numpy as np
import pandas as pd

from dataprep.clean import clean_country

# %% [markdown]
# # Exploring and preparing the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1 = pd.read_csv('/content/customers.csv')

# %%
# We know from domain knowledge that every row is a different sales order

# %%
df1.head()
# Out:
#          id+  days_since_purchase  frequency  revenue  \
# 0  AF1915092                  246          6  44712.0
# 1  AF1915452                  267          1  19908.0
# 2  AF1918074                  323          1  19428.0
# 3  AF1920168                  120          1  12942.0
# 4  AF2137002                  351          1  20994.0
#
#    log_days_since_purchase  log_frequency  log_revenue  Cluster_Prediction  \
# 0                     5.51           1.95        10.71                   2
# 1                     5.59           0.69         9.90                   2
# 2                     5.78           0.69         9.87                   2
# 3                     4.80           0.69         9.47                   2
# 4                     5.86           0.69         9.95                   2
#
#     segment
# 0  may lose
# 1  may lose
# 2  may lose
# 3  may lose
# 4  may lose

# %%
df1['country']=df1['id+'].apply(lambda x:x[0:2])

# %%
df1['country'].head
# Out:
# <bound method NDFrame.head of 0       AF
# 1       AF
# 2       AF
# 3       AF
# 4       AF
#         ..
# 5827    VN
# 5828    VN
# 5829    VN
# 5830    VN
# 5831    VN
# Name: country, Length: 5832, dtype: object>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5832 entries, 0 to 5831
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id+                      5832 non-null   object
#  1   days_since_purchase      5832 non-null   int64
#  2   frequency                5832 non-null   int64
#  3   revenue                  5832 non-null   float64
#  4   log_days_since_purchase  5832 non-null   float64
#  5   log_frequency            5832 non-null   float64
#  6   log_revenue              5832 non-null   float64
#  7   Cluster_Prediction       5832 non-null   int64
#  8   segment                  5832 non-null   object
#  9   country                  5832 non-null   object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 455.8+ KB

# %%
# Transforming country codes into full country names with clean_country function from dataprep library

df1['country_clean']=clean_country(df1, "country")['country_clean']
# Out:
# Country Cleaning Report:
# 	5832 values cleaned (100.0%)
# Result contains 5832 (100.0%) values in the correct format and 0 null values (0.0%)

# %%
df1.head()
# Out:
#          id+  days_since_purchase  frequency  revenue  \
# 0  AF1915092                  246          6  44712.0
# 1  AF1915452                  267          1  19908.0
# 2  AF1918074                  323          1  19428.0
# 3  AF1920168                  120          1  12942.0
# 4  AF2137002                  351          1  20994.0
#
#    log_days_since_purchase  log_frequency  log_revenue  Cluster_Prediction  \
# 0                     5.51           1.95        10.71                   2
# 1                     5.59           0.69         9.90                   2
# 2                     5.78           0.69         9.87                   2
# 3                     4.80           0.69         9.47                   2
# 4                     5.86           0.69         9.95                   2
#
#     segment country country_clean
# 0  may lose      AF   Afghanistan
# 1  may lose      AF   Afghanistan
# 2  may lose      AF   Afghanistan
# 3  may lose      AF   Afghanistan
# ...

# %%
# We export the dataframe to a CSV file for later processing it in Teabula
# (We added the parameter float_format='%.2f' for setting numbers to two decimals)

df1.to_csv('Segmentation customer with country..csv', encoding='utf-8', index=False, float_format='%.2f')
